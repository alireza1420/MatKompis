# %%
import pandas as pd
import re, json
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
import ast
from pathlib import Path

# %%
from pathlib import Path
def load_recipes():
    base = Path.cwd() / "recipes.csv"
    recipes = []
    try:
        df = pd.read_csv(base)
        for _, row in df.iterrows():
            recipes.append({
                "title": row["Title"],
                "ingredients": row["Ingredients"],
                "instructions": row["Instructions"],
                "image": row.get("Image_Name", ""),
                "cleaned_ingredients": row.get("Cleaned_Ingredients", "")
            })
        print(f"Loaded {len(recipes)} recipes")
    except Exception as e:
        print("Error loading recipes:", e)
    return recipes

RECIPES = load_recipes()
# Out:
# Loaded 13501 recipes

# %%
# LOAD PRODUCTS

def load_hemkop_jsons(folder: Path):
    products = []
    for file in folder.glob("hemkop_*.json"):
        try:
            with open(file, encoding="utf-8") as f:
                data = json.load(f)
                for item in data:
                    name = item.get("title")
                    nutrition = item.get("nutrition", {})
                    url = item.get("url", "")
                    products.append({
                        "name": name,
                        "store": "Hemköp",
                        "url": url,
                        "price": item.get("price"),
                        "nutrition": nutrition
                    })
        except Exception as e:
            print(f"Error reading {file}: {e}")
    return products

def load_ica_jsons(folder: Path):
    products = []
    for file in folder.glob("ica_*.json"):
        try:
            with open(file, encoding="utf-8") as f:
                data = json.load(f)
                for item in data:
                    name = item.get("title")
                    nutrition = item.get("nutrition", {})
                    url = item.get("url", "")
                    products.append({
                        "name": name,
                        "store": "Ica",
                        "url": url,
                        "price": item.get("price"),
                        "nutrition": nutrition
                    })
        except Exception as e:
            print(f"Error reading {file}: {e}")
    return products

def load_all_products():
    base = Path.cwd() / "data"
    hemkop_data = load_hemkop_jsons(base)
    ica_data = load_ica_jsons(base)
    products = hemkop_data + ica_data
    print(f"Loaded {len(products)} products ({len(hemkop_data)} Hemköp, {len(ica_data)} ICA)")
    return products

PRODUCTS = load_all_products()
product_names = [p["name"] for p in PRODUCTS]
# Out:
# Loaded 3424 products (805 Hemköp, 2619 ICA)

# %%
len(product_names)
# Out:
# 4852

# %%
product_names
# Out:
# ['Potatis Mjölig Klass 1',
#  'Potatis Fast Klass 1',
#  'Bakpotatis Klass 1',
#  'Potatis Fast Klass 1',
#  'Sötpotatis Klass 1',
#  'Potatis Delikatess Klass 1',
#  'Potatis Fast Klass 2',
#  'Potatis Amandine Klass 1',
#  'Potatis Mjölig Klass 2',
#  'Potatis Smått&gott Klass 1',
#  'Potatis Fast Eko Klass 2',
#  'Potatis Delikatess Klass 1',
#  'Potatis Fast Klass 1',
#  'Potatis Kok Stor Klass 1',
#  'Potatis Smått&gott Klass 1',
#  'Potatis Mjölig Klass 1',
#  'Sötpotatis Eko',
#  'Potatis Fast Klass 2',
#  'Potatis Mjölig Klass 2',
#  'Kycklingkebab Fryst',
#  'Kyckling Lårfilé Svensk',
#  'Kycklingfilé Bröstfilé Sverige',
#  'Kycklinglårfil Färsk Sverige',
#  'Kycklingfilé Strimlad Sverige',
#  'Majskyckling Hel Sverige',
#  'Kycklingben Marinerade Sverige',
#  'Kycklingben Färska Sverige',
#  'Kyckling Bröstfilé Sverige',
#  'Kyckling Hel Färsk Sverige',
#  'Majskyckling Bröstfilé Sverige',
#  'Kycklingklubba Sverige',
#  'Kyckling Ben Frysta',
#  'Kyckling Vingar Frysta',
#  'Kycklinglår Frysta',
#  'Kyckling Klubba Fryst',
#  'Kyckling Köttbullar',
#  'Kyckling Nuggets',
#  'Kyckling Burgare 10x90g',
#  'Innerfilé av Svensk Kyckling Fryst',
#  'Kyckling Filé Svensk Fryst',
#  'Kyckling Innerfilé Fryst',
#  'Kyckling Filé Fryst',
#  'Kyckling Filé Fryst',
#  'Kycklingsteak Sverige',
#  'Kycklingfilé Sverige',
#  'Kycklinglår Sverige',
#  'Kyckling Lårfilé Sverige',
#  'Ätklar Taco Kyckling Skivad',
#  'Kyckling Lårfilé Sverige',
#  'Minutbitar Kyckling',
#  'Gårdskyckling',
#  'Kycklingmage Sverige',
#  'Ceasar Ätklar Kyckling Skivad',
#  'Ätklar Bbq Kyckling Skivad',
#  'Kycklinglever Sverige',
#  'Ätklar Classic Kyckling Skivad',
#  'Minutstrimlor Kycklingfilé',
#  'Kycklinghjärta Sverige',
#  'Kycklingsteak Ranch',
#  'Ätklar Caesar Kyckling',
#  'Innerfilé Kyckling Små Fina',
#  'Kycklingben Sverige',
#  'Minutfilé Kyckling',
#  'Kycklingfilé Sverige',
#  'Soltorkad Tomat Ätklart Kyckling Skivad',
#  'Chicken Nuggets Crispy Frysta',
#  'Drumsticks Chicken Bbq Fryst',
#  'Kycklingspett Grillade Fryst',
#  'Drumsticks Chicken Bbq Fryst',
#  'Chicken Drumsticks Grillade Frysta',
#  'Chicken Kebab Fryst',
#  'Sallads Kyckling',
#  'Buffalo Wings Frysta',
#  'Kycklinggyros Fryst',
#  'Chicken Nuggets Frysta',
#  'Buffalo Wings Grillade Frysta',
#  'Tacokyckling Fryst',
#  'Chicken Rings Frysta',
#  'Kycklingbröst Filé Svensk',
#  'Kyckling Hel Färsk Svensk',
#  'Kyckling Lårfilé Sverige',
#  'Kyckling Bröstfilé Sverige',
#  'Crispy Kycklingburgare Fryst',
#  'Delifresh Kycklingburgare Frysta',
#  'Kycklingpinnar Frysta',
#  'Nuggets Kyckling Frysta',
#  'Nuggets Kyckling Frysta',
#  'Kycklinginnerf Grillad Bbq Smak Sverige',
#  'Kyckling Bröstfilé Sverige',
#  'Kyckling Bröstfilé Sverige',
#  'Kycklingbröst Strimlat Marinerat Korean',
#  'Chicken Nugget Lagat & Klart Sverige',
#  'Kyckling Grillad Tärnad Sverige',
#  'Majskyckling Lårfilé Sverige',
#  'Kycklingfilé Tunnskivad Sverige',
#  'Kyckling Panaeng Red Curry Sverige',
#  'Kycklingfilé Tvådelad Sverige',
#  'Majskyckling Innerfilé Sverige',
#  'Köttbullar Kalkon Små Frysta',
#  'Kalkonfärs Fryst Fryst',
#  'Kyckling Innerfilé Fryst',
#  'Kycklingfilé Fryst',
#  'Kycklingbröst Filé Import',
#  'Kyckling Innerfilé Import',
#  'Kycklingvingar Import',
#  'Kyckling Lårfilé Import',
#  'Kycklingklubba Import',
#  'Kycklingben Import',
#  'Buffalo Wings Grillkryddad/sverige',
#  'Kyckling Bröstfilé Sverige',
#  'Kycklingfilé Tunna Skivor',
#  'Kyckling Lårfilé Sverige',
#  'Kycklingben Sverige',
#  'Lårfilè Majskyckling',
#  'Bröstfilè Majskyckling',
#  'Tunnskivad Kalkonbröstfilé',
#  'Kalkonbröstfil',
#  'Kalkonbröst Sverige',
#  'Jasminris Boil-in-bag 4x125g',
#  'Basmati Boil-in-bag 4x125g',
#  'Långkornigt Ris Boil-in-bag 4x125g',
#  'Mathavre Svensk',
#  'Matvete',
#  'Kvarngryn Svenska',
#  'Långkornigt Ris',
#  'Långkorn 10min Ris',
#  'Jasminris',
#  'Couscous',
#  'Couscous',
#  'Basmatiris',
#  'Jasminris',
#  'Jasminris Boil-in-bag 4x125g',
#  'Jasminris',
#  'Jasminris',
#  'Jasminris',
#  'Basmatiris',
#  'Basmatiris',
#  'Kornris Svenskt',
#  'Havreris Svenskt',
#  'Quinoa Tricolore',
#  'Potatismos Klassiskt 33 Port',
#  'Potatismos 12 Port',
#  'Potatismos Klassiskt 6 Port',
#  'Couscous Eko',
#  'Basmati 1121 Ris',
#  'Basmati Ris',
#  'Basmatiris 1121 Extra Långa Fina',
#  'Basmatiris',
#  'Potatismos 3-pack/12 Port',
#  'Råris',
#  'Långkornigt Ris',
#  'Jasminris',
#  'Jasminris Boil-in-bag 4x125g',
#  'Grötris',
#  'Basmatiris Boil-in-bag 4x125g',
#  'Basmatiris',
#  'Basmatiris',
#  'Rött Ris',
#  'Arborioris',
#  'Svart Ris',
#  'Vit Quinoa',
#  'Röd Quinoa',
#  'Fullkornsris Boil-in-bag 4x125g',
#  'Långkornigt Ris Boil-in-bag 4x125g',
#  'Långkornigt Ris',
#  'Långkornigt Ris',
#  'Långkorn 10min Ris',
#  'Fullkornsris',
#  'Fullkornsris',
#  'Bulgur av Durumvete',
#  'Grov Bulgur av Durumvete',
#  'Pärlcouscous',
#  'Ris Långkornigt',
#  'Långkornigt Ris',
#  'Bulgur Ekologisk av Durumvete',
#  'Basmatiris Boil-in-bag 4x125g',
#  'Basmatiris',
#  'Carnaroli Ris',
#  'Arborioris Rundkornigt Till Risotto',
#  'Carnaroli Gran Riserva Ris',
#  'Arborioris',
#  'Jasminris Långkornigt',
#  'Basmatiris Långkornigt',
#  'Basmati Rice Pure',
#  'Avorio Risottoris',
#  'Grötris',
#  'Mahmood Basmatiris',
#  'Grötris Polerat',
#  'Basmatiris Boil-in-bag 4x125g',
#  'Jasminris Boil-in-bag 4x125g',
#  'Vete Asurelik Skalad',
#  'Bulgur Fullkorn',
#  'Bulgur Fin Köftelik',
#  'Bulgur Grov med Rostade Nudlar',
#  'Bulgur Mellan Pilavlik Midyat',
#  'Bulgur Grov Pilavlik',
#  'Polenta',
#  'Långkornigtris Boil-in-bag 4x125g',
#  'Korngryn',
#  'Jasminrice Fragrant',
#  'Libanesiskt Ris',
#  'Röd Quinoa',
#  'Quinoa',
#  'Basmati Ris',
#  'Medelkornigt Vitt Ris',
#  'Baguette Vete',
#  'Grötbröd',
#  'Energibröd Osötat Fullkorn',
#  'Pågenlimpan',
#  'Längtan',
#  "Roast'n Toast",
#  'Rasker Fullkorn',
#  'Jättefranska',
#  'Rosta',
#  'Hönökaka 4-pack',
#  'Skärgårdskaka Hönö 18-pack',
#  'Himla Go',
#  'Fullkornsbröd med Linfrön 8-skivor Fullkronsrå',
#  'Frölimpa Mörk',
#  'Levain',
#  'Grekiskt Lantbröd',
#  'Råglevain',
#  'Lantgoda Surdegsbröd',
#  'Grötfrallor 4-pack',
#  'Guldkorn',
#  'Skanörgrova',
#  'Lingongrova',
#  'Lingongrova Special',
#  'Fullkornsgott Osötat Bröd Surdeg Lin Och Solrosfrö',
#  'Jubileumsbröd Halmstad Stenugnsbakat',
#  'Hembakat Stenugnsbakad Skivad',
#  'Hälsa Lågt Gi Bakad i Stenugn',
#  'Rund & Sund',
#  'Bondbröd Runt',
#  'Sportbröd Skivat',
#  'Vallmorost Luftigt Saftigt',
#  'Brioche Rostbröd',
#  'Vital Grovt Bröd Fyllt av Råg',
#  'Lingon Grovt Bröd',
#  'Proteinbröd 5-skivor',
#  'Superbröd Tranbär',
#  'Pumpernickel',
#  'Baguette Halv Vete 2-pack',
#  'Minibaguette Vete 4-pack',
#  'Ostfralla 4-pack',
#  'Korvbröd 16-pack',
#  'Korvbröd 10-pack',
#  'Rågbröd Bosses',
#  'Fruktkusar 6-pack',
#  'Rågform 8-pack',
#  'Rågkusar 12-pack',
#  'Proteintoast',
#  'Tunnbröd Ljust Libanesiskt Uvs',
#  'Rågbröd Grovt 6-pack',
#  'Rågbröd Solros/pumpa 6-pack',
#  'Fröbröd 4-pack',
#  'Orientbröd Vete 4-pack',
#  'Rågbröd Maltigt 6-pack',
#  'Rågkaka 30-pack',
#  'Vetekaka 24-pack',
#  'Ostbröd 4-pack',
#  'Rågbröd Mustigt 6-pack',
#  'Orientbröd Råg 4-pack',
#  'Surdegsfralla Durum 4-pack',
#  'Lantbröd Havssalt',
#  'Frörost Fullkorn',
#  'Ostrost',
#  'Rostbröd',
#  'Rågbröd Danskt',
#  'Levainrost',
#  'Rågkaka 30-pack',
#  'Rågkaka 6-pack',
#  'Hällakaka 5-pack',
#  'Fiberrost',
#  'Frasrost',
#  'Originalrost Skivad',
#  'Varsågod Skivad',
#  'Limpa Skogaholm',
#  'Surdegsfralla Mörk 4-pack',
#  'Jubileumskaka Vallmo',
#  'Hamburgerbröd 8-pack',
#  'Baguette Eko',
#  'Hamburgerbröd 4-pack',
#  'Mjuka Fröbitar',
#  'Prosciutto Crudo Skivad',
#  'Nötfärs 12% Sverige',
#  'Skinka Basturökt Skivad',
#  'Rökt Skinka Svea Skivad',
#  'Skinka Långkokt Skivad',
#  'Pepparsalami Deliskivor',
#  'Salami Chipotle Deliskivor',
#  'Salami Milano Deliskivor',
#  'Vitlökssalami Deliskivor',
#  'Mortadella Kyckling Paprika Skivad',
#  'Baharatli Dili Kalkon Mortadella Skivad',
#  'Tavuk Dilim Kyckling Mortadella Skivad',
#  'Sade Dilim Kalkon Mortadella Skivad',
#  'Mammut Oliver',
#  'Oliver Vitlök',
#  'Oliver med Chili',
#  'Vit Ost Mix Oliver',
#  'Kycklingkebab Fryst',
#  'Grillkorv med Skinn',
#  'Kyckling Lårfilé Svensk',
#  'Blandfärs 21%',
#  'Ölkorv Vitlök',
#  'Het Chili Ölkorv',
#  'Ölkorv Chili',
#  'Ölkorv Original',
#  'Ost&bacon Grillkorv',
#  'Scorpion Chili Trinidad Kryddkorv',
#  'Tryffelkorv',
#  'Kabanoss',
#  'Kabanoss Smal',
#  'Bratwurst',
#  'Chorizo Jalapeño Smal',
#  'Chorizo',
#  'Saltrulle Deliskivor',
#  'Skinka Flatrökt',
#  'Pastrami Deliskivor',
#  'Kyckling Rökt Deliskivor',
#  'Kyckling Grillad Deliskivor',
#  'Skinka Extrarökt Deliskivor',
#  'Cognacs Medwurst Deliskivor',
#  'Kokt Skinka Deliskivor',
#  'Basturökt Skinka Deliskivor',
#  'Bacon Rökt & Skivat',
#  'Piccante Salame',
#  'Tryffelsalami',
#  'Fänkålssalami',
#  'Kycklingkebab Sverige',
#  'Gyros Kebab Sverige',
#  'Rökt Skinka Strimlad',
#  'Grillkorv Kyckling',
#  'Kyckling- Chorizo',
#  'Kycklinglårfil Färsk Sverige',
#  'Kycklingfilé Bröstfilé Sverige',
#  'Leverpastej Original Bredbar',
#  'Leverpastej Gurka Bredbar',
#  'Falukorv',
#  'Nötfärs 15%',
#  'Köttbullar Kyckling',
#  'Grillkorv Hög Kötthalt',
#  'Fuet Tradicional Lufttorkad Salami',
#  'Prosciutto Deliskivor',
#  'Rostbiff Deliskivor',
#  'Kycklingfilé Strimlad Sverige',
#  'Kyckling Bröstfilé Sverige',
#  'Kycklingklubba Sverige',
#  'Majskyckling Hel Sverige',
#  'Kycklingben Marinerade Sverige',
#  'Kycklingben Färska Sverige',
#  'Kyckling Hel Färsk Sverige',
#  'Majskyckling Bröstfilé Sverige',
#  'Kycklingfärs Naturell Sverige',
#  'Kycklingbacon Rökt med Alspån',
#  'Köttbullar Färdiglagade',
#  'Köttbullar Delikatess',
#  'Köttbullar Färdiglagade',
#  'Köttbullar',
#  'Arbogapastej Original Bredbar',
#  'Kokt Skinka Tunna Skivor',
#  'Rökt Skinka Tunna Skivor',
#  'Rökt Kyckling Tunna Skivor',
#  'Tärnat Bacon',
#  'Lördagskorv Skivad',
#  'Jaktkorv Skivad',
#  'Gotler Skivad',
#  'Stekfläsk Skivat',
#  'Skivat Bacon Originalet',
#  'Bacon Miniskivat',
#  'Skivat Bacon Ekologiskt Skivad',
#  'Skivat Bacon 3-pack',
#  'Grillkorv Kyckling Tjock',
#  'Bacon Rökt & Tärnat',
#  'Wienerkorv',
#  'Wienerkorv Kyckling',
#  'Wienerkorv',
#  'Ölkorv Original 3-pack',
#  'Ölkorv Vitlök 3-pack',
#  'Het Chili Ölkorv 3-pack',
#  'Het Chili Ölkorv 3-pack',
#  'Ölkorv Chili 3-pack',
#  'Kalkonbacon',
#  'Varmkorv',
#  'Varmkorv',
#  'Fläskfärs 20% Sverige',
#  'Högrevsfärs 13% Sverige',
#  'Nöt & Grönt Nötkött Grönsaker Sverige',
#  'Nötfärs 5% Sverige',
#  'Blandfärs 20% Sverige',
#  'Fläskfärs 20% Sverige',
#  'Blandfärs 20% Sverige',
#  'Hamburgerfärs',
#  'Blandfärs 20% Sverige',
#  'Nötfärs 12% Sverige',
#  'Blandfärs 20% Sverige',
#  'Nötfärs 12% Sverige',
#  'Nötfärs 12% Sverige',
#  'Nötfärs 12% Sverige',
#  'Rökt Kalkon Tunna Skivor Skivad',
#  'Salame Milano Skivad',
#  'Prosciutto Crudo Skivad',
#  'Prosciutto Di Parma Skivad',
#  'Salame Ventricina Skivad',
#  'Antipasti Skivad',
#  'Grillkorv Tjock Skinnfri',
#  'Klassisk Kebab',
#  'Big-pack Kebab',
#  'Kyckling Vingar Frysta',
#  'Kycklinglår Frysta',
#  'Kyckling Ben Frysta',
#  'Sylta Småländsk med Kalvkött',
#  'Kalvsylta Småländsk',
#  'Gourmetskinka Basturökt Skivad',
#  'Kalkon Rökt Tunna Skivor',
#  'Medwurst Kokt Skivad',
#  'Rökt Salami Tunna Skivor',
#  'Hushålls Medwurst Skivad',
#  'Gourmetskinka Rökt Skivad',
#  'Cognacs- Medwurst Skivad',
#  'Gourmetskinka Kokt Skivad',
#  'Kyckling Köttbullar',
#  'Kyckling Nuggets',
#  'Kyckling Burgare 10x90g',
#  'Vår Rökigaste Skinka Skivad',
#  'Extrarökt Skinka Skivad',
#  'Kalkon Basturökt Skivad',
#  'Lindösalami Peppar Skivad',
#  'Kyckling Medvurst Skivad',
#  'Kyckling Grillad Skivad',
#  'Ugnsrostad Skinka Skivad',
#  'Skinka Basturökt Skivad',
#  'Kokt Skinka Skivad',
#  'Extrarökt Kyckling Skivad',
#  'Grillkorv Hots',
#  'Barnens Grillkorv',
#  'Kyckling Klubba Fryst',
#  'Cognacmedwurst Enrisrökt',
#  'Cognacmedwurst Alspånsrökt',
#  'Chorizo Bbq Hot',
#  'Bratwurst Nürnberger',
#  'Chorizo Bbq Mild',
#  'Grillkorv Kyckling',
#  'Kalkonbröst Basturökt',
#  'Rökta Skinka Bror Jakobs Skivad',
#  'Gallerrökt Skinka Skivad Pepparkryddad',
#  'Gallerrökt Skinka Skivad',
#  'Rökta Bog Skivad',
#  'Svartrökta Skinka Skivad Bror Jakobs',
#  'Kokta Skinka Skivad Mor Matildas',
#  'Rostbiff Grillad',
#  'Tärnat Bacon',
#  'Husmorspastej Grädd',
#  'Falukorv',
#  'Falukorv Delikatess',
#  'Leverpastej med Gurka Bredbar',
#  'Kycklingpastej Bredbar',
#  'Mild & Krämig Leverpastej Bredbar',
#  'Mustig&smakrik Leverpastej Bredbar',
#  'Leverpastej Bredbar',
#  'Original Leverpastej 2-pack',
#  'Skivat Bacon',
#  'Skivat Bacon 3-pack',
#  'Pancetta',
#  'Rostbiff Vinmarinerad',
#  'Kalkonbröst Rökt Skivad',
#  'Prinskorv',
#  'Isterband Småländska Långa',
#  'Leverpastej Grädd Ungsbakad Deli',
#  'Leverpastej Ugnsbakad Ekologisk',
#  'Leverpastej Svensk Bredbar',
#  'Leverpastej Ugnsbakad Bredbar',
#  'Lammkorv',
#  'Kabanoss',
#  'Chistorra',
#  'Serranolindad Manchego',
#  'Kyckling Filé Svensk Fryst',
#  'Burgare Nöt & Grönt',
#  'Högrevsburgare Fetthalt 13% Sverige',
#  'Arbogapastej Original Skivbar',
#  'Arbogapastej Original Skivbar',
#  'Salamino Peperoni',
#  'Salame Milano Skivad',
#  'Prosciutto Crudo',
#  'Prosciutto Di Parma Skivad',
#  'Salame Napoli Skivad',
#  'Tomater Babyplommon Kvist Klass 1',
#  'Pumpa Butternut',
#  'Majskolv',
#  'Babyspenat Ekologisk Klass 1',
#  'Ruccola Ekologisk Klass 1',
#  'Mache Sallad Eko Klass 1',
#  'Småbladsmix Ruccola Röd/grön Klass 1',
#  'Tomat Cockt Eko Klass 1',
#  'Lök Vit Morado Klass 1',
#  'Gurka Sverige Klass 1',
#  'Avokado Klass 1',
#  'Spetspaprika Röd Klass 1',
#  'Lök Gul Klass 1',
#  'Lök Röd Klass 1',
#  'Paprika Röd Klass 1',
#  'Kvisttomat Import Klass 1',
#  'Småbladsmix Ruccola Röd/grön Klass 1',
#  'Babyspenat',
#  'Tomater Kvist Sverige Klass 1',
#  'Tomat Sverige Klass 1',
#  'Paprika Gul Klass 1',
#  'Tomat Klass 1',
#  'Frisé Mache Klass 1',
#  'Sallat Cosmopolitan Klass 1',
#  'Salladsmix Klass 1',
#  'Böngroddar Ekologisk',
#  'Grönkål Eko',
#  'Babyspenat Klass 1',
#  'Babyspenat Klass 1',
#  'Fänkål Klass 1',
#  'Isberg Frisé Klass 1',
#  'Aubergine Klass 1',
#  'Paprika Grön Klass 1',
#  'Ruccola Klass 1',
#  'Tomatmix Klass 1',
#  'Kronärtskocka',
#  'Blandsallad Klass 1',
#  'Rödbeta Röd Mangold Klass 1',
#  'Gourmetsallad Klass 1',
#  'Sallad Nouvell Klass 1',
#  'Kålmix Rödkål & Grönkål Klass 1',
#  'Tomat San Marzano Klass 1',
#  'Kålmix Vitkål&morot Klass 1',
#  'Frisé & Maché Klass 1',
#  'Alfalfagroddar Ekologisk',
#  'Romansallad Klass 1',
#  'Kvisttomater Eko Klass 1',
#  'Rökt Skinka Svea Skivad',
#  'Skinka Basturökt Skivad',
#  'Skinka Långkokt Skivad',
#  'Pepparsalami Deliskivor',
#  'Salami Milano Deliskivor',
#  'Salami Chipotle Deliskivor',
#  'Vitlökssalami Deliskivor',
#  'Baharatli Dili Kalkon Mortadella Skivad',
#  'Sade Dilim Kalkon Mortadella Skivad',
#  'Mortadella Kyckling Paprika Skivad',
#  'Tavuk Dilim Kyckling Mortadella Skivad',
#  'Kokt Skinka Deliskivor',
#  'Pastrami Deliskivor',
#  'Skinka Extrarökt Deliskivor',
#  'Cognacs Medwurst Deliskivor',
#  'Skinka Flatrökt',
#  'Kyckling Grillad Deliskivor',
#  'Kyckling Rökt Deliskivor',
#  'Saltrulle Deliskivor',
#  'Basturökt Skinka Deliskivor',
#  'Leverpastej Gurka Bredbar',
#  'Leverpastej Original Bredbar',
#  'Fuet Tradicional Lufttorkad Salami',
#  'Prosciutto Deliskivor',
#  'Rostbiff Deliskivor',
#  'Arbogapastej Original Bredbar',
#  'Rökt Kyckling Tunna Skivor',
#  'Rökt Skinka Tunna Skivor',
#  'Kokt Skinka Tunna Skivor',
#  'Gotler Skivad',
#  'Jaktkorv Skivad',
#  'Lördagskorv Skivad',
#  'Rökt Kalkon Tunna Skivor Skivad',
#  'Sylta Småländsk med Kalvkött',
#  'Kalvsylta Småländsk',
#  'Gourmetskinka Rökt Skivad',
#  'Gourmetskinka Basturökt Skivad',
#  'Cognacs- Medwurst Skivad',
#  'Hushålls Medwurst Skivad',
#  'Gourmetskinka Kokt Skivad',
#  'Rökt Salami Tunna Skivor',
#  'Medwurst Kokt Skivad',
#  'Kalkon Rökt Tunna Skivor',
#  'Ugnsrostad Skinka Skivad',
#  'Kyckling Medvurst Skivad',
#  'Extrarökt Skinka Skivad',
#  'Skinka Basturökt Skivad',
#  'Kokt Skinka Skivad',
#  'Kyckling Grillad Skivad',
#  'Lindösalami Peppar Skivad',
#  'Vår Rökigaste Skinka Skivad',
#  'Kalkon Basturökt Skivad',
#  'Extrarökt Kyckling Skivad',
#  'Cognacmedwurst Enrisrökt',
#  'Cognacmedwurst Alspånsrökt',
#  'Kokta Skinka Skivad Mor Matildas',
#  'Rostbiff Grillad',
#  'Gallerrökt Skinka Skivad Pepparkryddad',
#  'Gallerrökt Skinka Skivad',
#  'Rökta Skinka Bror Jakobs Skivad',
#  'Rökta Bog Skivad',
#  'Kalkonbröst Basturökt',
#  'Svartrökta Skinka Skivad Bror Jakobs',
#  'Husmorspastej Grädd',
#  'Original Leverpastej 2-pack',
#  'Mild & Krämig Leverpastej Bredbar',
#  'Leverpastej med Gurka Bredbar',
#  'Leverpastej Bredbar',
#  'Kycklingpastej Bredbar',
#  'Mustig&smakrik Leverpastej Bredbar',
#  'Kalkonbröst Rökt Skivad',
#  'Rostbiff Vinmarinerad',
#  'Leverpastej Svensk Bredbar',
#  'Leverpastej Ugnsbakad Ekologisk',
#  'Leverpastej Ugnsbakad Bredbar',
#  'Leverpastej Grädd Ungsbakad Deli',
#  'Peperoni Pizza Salami Skivad',
#  'Macar Salami Kalkon Skivad',
#  'Arbogapastej Original Skivbar',
#  'Arbogapastej Glutenfri Mjölkfri Skivbar',
#  'Arbogapastej Original Skivbar',
#  'Klassisk Grov Leverpastej',
#  'Pepparsalami Skivad',
#  'Chorizosalami Skivad',
#  'Pepperonisalam Skivad',
#  'Vitlökssalami Skivad',
#  'Dansk Salami Klassisk Skivad',
#  'Ravioli i Tomatsås',
#  'Leverpastej Skivbar',
#  'Alspånsrökt Kalkonbröst Skivad',
#  'Extrarökt Kalkonbröst Skivad',
#  'Pastrami Kalkonbröst Skivad',
#  'Örtpastej Vegetarisk Pålägg',
#  'Läckökorv Kallrökt Skivad',
#  'Olivmortadell Skivad',
#  'Medwurst Kokt Skivad',
#  'Prickig Korv Kallrökt Skivad',
#  'Lammsalami Skivad',
#  'Guldsalami Skivad',
#  'Pepparsalami Skivad',
#  'Tryffelsalami Haga-petters Skivad',
#  'Chilisalami Haga-petters Skivad',
#  'Salami Haga-petters Skivad',
#  'Kyckling Grillad Ojämna Skivor',
#  'Pepparsalami Skivad',
#  'Pepperoni Salami Skivad',
#  'Vitlökssalami Skivad',
#  'Salami Klassisk Skivad',
#  'Ravioli i Köttsås',
#  'Chili Con Carne',
#  'Hästkött Granrökt Skivad',
#  'Rökt Skinka Skivad',
#  'Hönsbröstfile Basturökt Skivad',
#  'Rökt Kalkon Skivad',
#  'Kokt Skinka Skivad',
#  'Hushållswurst Medwurst Skivad',
#  'Salami Skivad',
#  'Cognacswurst Skivad',
#  'Rökt Kyckling Skivad',
#  'Vinbladsdolmar',
#  'Rökt Skinka Ekologiskt Skivad Smörgåspålägg',
#  'Kokt Skinka Ekologiskt Skivad Smörgåspålägg',
#  'Originalet Bit',
#  'Wild Chips',
#  'Rökt Skinka',
#  'Kyckling Lättrökt',
#  'Skinka Långkokt',
#  'Ravioli Bolognese',
#  'Ravioli Vegetarisk',
#  'Leverpastej Skivbar',
#  'Chorizo Sarta Ring',
#  'Burkskinka',
#  'Picnic Bog',
#  'Köttbullar i Gräddsås',
#  'Varmkorv',
#  'Pilsnerkorv',
#  'Norrlandspölsa',
#  'Kalkonpastej',
#  'Kycklingpastej 4-pack',
#  'Kycklingpastej',
#  'Kycklingpastej Pikant',
#  'Kycklingpastej Original',
#  'Kycklingpastej Halal',
#  'Original Junior Kyckling',
#  'Chorizo Sarta Mild',
#  'Chorizo Sarta Spicy',
#  'Fuet',
#  'Iberico Chorizo',
#  'Salami Turist',
#  'Med Oliver Kycklingmortadella Skivad',
#  'Fuet Iberico',
#  'Fuet Truffle',
#  'Fläskfilégryta med Cocktailpølser Och Bacon',
#  'Paprika Kycklingsalami',
#  'Kycklingkorv med Ost',
#  'Picant Kycklingsalami',
#  'La Salsiccia Di Pollo Kycklingkorv Liten',
#  'Corned Beef Original',
#  'Läckökorv Kallrökt Bit',
#  'Rostbiff Grillad',
#  'Gallerrökta',
#  'Lunchkorv Kyckling Halal',
#  'Kycklingpastej Lovacka',
#  'Oxskivor',
#  'Napoli Salamino',
#  'Fläsk Luncheon',
#  'Mortadella Kyckling Oliver',
#  'Mortadella Kyckling Pistage',
#  'Mortadella Kyckling Paprika',
#  'Pizzasalami',
#  'Kycklingpastej Classic',
#  'Hönspastej Classic',
#  'Rökt Skinka Ekologisk Skivad',
#  'Kyckling Luncheon',
#  'Chicken Luncheon Meat',
#  'Kyckling Luncheon Hot & Spicy',
#  'Kyckling Lunchkorv',
#  'Mage i Tomatsås med Grönsaker',
#  'Paté Gammaldags',
#  'Guven Sucuk',
#  'Parmak Sucuk',
#  'Fasolka Gospodarza Bön&korv i Tomatsås',
#  'Pepparsalami Skivad',
#  'Salami Danish Style Skivad',
#  'Sudjuk Kosovo',
#  'Chicken Salami Extra',
#  'Bönor Fläsk i Sås',
#  'Gustafskorv Halv Ring',
#  'Vitlökssalami Skivad',
#  'Cajna Salami',
#  'Chicken Luncheon Hot Spicy',
#  'Suxhuk Shtepjak',
#  'Lunchkorv Hot Kyckling',
#  'Salami Ojämna Skivor',
#  'Pastirma Bahar',
#  'Wudy Pop! Kyckling&kalkon Salami',
#  'Laxfilé C-trim',
#  'Frasig Firre Panerad Alaska Frysta/4 Port',
#  'Torskfilé Portionbitar Frysta',
#  'Tärningar Torsk Och Lax',
#  'Fiskfiléer Frasiga Glutenfria Frysta/4-pack',
#  'Fish & Crisp Gourmetfiléer',
#  'Torskfiléer Sprödbakade Frysta/4-pack',
#  'Alaska Pollock Fryst/4-pack',
#  'Torskfilé Sprödbakad',
#  'Torskfilé Fina Frysta/3-pack',
#  'Torskfilé Fryst',
#  'Torskryggfilé Frysta/3-pack',
#  'Fiskpinnar Frysta/15-pack',
#  'Fish&fun',
#  'Fiskpinnar Frysta/30-pack',
#  'Fiskpinnar Frasiga Frysta/15-pack',
#  'Fiskpinnar Gf',
#  'Torskryggfilé',
#  'Laxfilé Frysta/4x125g',
#  'Laxburgare Frysta/4 Port',
#  'Fish & Crisp Nuggets Frysta/ca. 20-pack',
#  'Crispies Krispiga Godbitar Frysta/8-pack',
#  'Pangasius Frysta',
#  'Fiskpinnar Spröda Frysta/15-pack',
#  'Varmrökt Lax Citronpeppar Portionsbit',
#  'Kallrökt Lax Skivad',
#  'Regnbågslax Varmrökt Hel',
#  'Gravad Lax Skivad',
#  'Gravad Lax Skivad',
#  'Varmrökt Lax Naturell Portionsbit',
#  'Varmrökt Lax Chimichurri Portionsbit',
#  'Kallrökt Lax Skivad',
#  'Varmrökt Lax Naturell Dubbelbit',
#  'Makrillfilé Varmrökt Svart Peppar',
#  'Laxfilé Fryst',
#  'Pinklax Portionsbitar Fryst',
#  'Laxbitar Fryst',
#  'Gulskäddafilé',
#  'Regnbågslax',
#  'Lax Back Loin 1/2',
#  'Sejfelé',
#  'Ryggfilé Stillahavstorsk',
#  'Panerad Sej Förstekt',
#  'Laxburgare 2-pack',
#  'Flundra Stillahavs Fryst',
#  'Fish &chips Filèer',
#  'Sprödbakad Kummel',
#  'Sillfiléer Refresh',
#  'Sushilax',
#  'Laxfilé Bit Benfri',
#  'Laxfilé i Bit Refreshed',
#  'Laxfilé 4x125 G 4-pack',
#  'Torskrygg Skinn O Benfri',
#  'Sejfilé Skinn Och Benfri',
#  'Lax Grytbitar',
#  'Torskfilé Skinn O Benfri Refreshed',
#  'Laxfilè C-trim',
#  'Sillfilè',
#  'Makrillfilè',
#  'Fish Bites Crispy',
#  'Laxfärs Fryst',
#  'Najadlax Skivad',
#  'Laxfilé Chili Varmrökt Sesam',
#  'Gravad Laxfilé Skivad',
#  'Kallrökt Laxfilé',
#  'Makrillfilé Varmrökt Svartpeppar',
#  'Laxfile Varmrökt',
#  'Varmrökt Lax Dubbel i Bit',
#  'Torskfilé',
#  'Fisk Nuggets',
#  'Fish Cakes Braxen Och Böna Frysta',
#  'Varmrökt Lax',
#  'Varmrökt Lax Hel',
#  'Laxfilé Bit',
#  'Spåtta Stillahavet',
#  'Köttbuljong 12-p 132g ICA',
#  'Gammaldags Idealmakaroner 750g Kungsörnen',
#  'Nudlar Kycklingsmak 85g Samyang',
#  'Tonfisk i olja 170g ICA',
#  'Kokosgrädde 200ml Kung markatta',
#  'Lingonsylt 1,5Kg ICA Basic',
#  'Vitlökspulver 49g Santa Maria',
#  'Champinjoner Skivade 290g ICA',
#  'Taco sauce Medium 230g Santa Maria',
#  'Granola Kanel mandel & äpple 450g Paulúns',
#  'Lingon Rårörda 750g ICA',
#  'Majskorn 340g ICA',
#  'Vetemjöl 1kg ICA',
#  'Svartpeppar grovmalen 65g ICA Basic',
#  "Chokladdryck Original Refill 700g O'boy",
#  'Minimajs 425g ICA Asia',
#  'Vita bönor i tomatsås 415g Heinz',
#  'Flingsalt 200g ICA',
#  'Soltorkade tomater Strimlade med örter 100g ICA',
#  'Rapsolja ICA 1000ml Basic',
#  'Gröna linser 380g ICA',
#  'Mango chutney Original 300g ICA Asia',
#  'Pasta Tortellini Ricottaost & Spenat Färsk 250g ICA',
#  'Gammaldags Idealmakaroner 1300g Kungsörnen',
#  'Oregano 15g ICA Basic',
#  'Spaghetti 1kg Kungsörnen',
#  'Majonnäs 450g ICA',
#  'Nachochips 200g ICA',
#  'Äppelmos 720g ICA Basic',
#  'Snabbkaffe Original Mellanrost Refill 200g Gevalia',
#  'Oliver Gröna med Pimiento 340g Figaro',
#  'Torkad Mango 200g Sunshine Delights',
#  'Pasta Gnocchi Färsk 400g ICA',
#  'Kanel Malen påse 55g Santa Maria',
#  'Jordgubbssylt 620g ICA',
#  'Kycklingfond 180ml Touch of Taste',
#  'Bönor Svarta Ekologisk 380g Zeta',
#  'Spirali 500g ICA',
#  'Smörgåsgurka Mor annas 590g Önos',
#  'Kaffefilter 1x4 oblekta 80-p ICA',
#  'Lasagneplattor 500g ICA',
#  'Snabbmakaroner 750g Kungsörnen',
#  'Tomater passerade 500g ICA Basic',
#  'Frukostflingor Havrekuddar Original 375g Havrefras',
#  'Marinad BBQ Chicken 75g Santa Maria',
#  'Plommon urkärnade 250g ICA',
#  'Finkrossade Tomater 390g ICA',
#  'Spaghetti 1kg ICA Basic',
#  'Kikärtor Ekologisk 380g Zeta',
#  'Bryggkaffe Mellanrost 450g Löfbergs',
#  'Pasta Tagliatelle 500g Barilla',
#  'Tortilla Chips Che 185g Santa Maria',
#  'Chunky salsa Medium 230g Santa Maria',
#  'Finkornigt Hushållssalt med jod 1kg Falksalt',
#  'Olivolja Extra virgin 750ml ICA',
#  'Taco Tubs 145g Santa Maria',
#  'Kakao 200g ICA',
#  'Jasminris 2kg ICA Asia',
#  'Korv Stroganoff Kryddmix 50g Knorr',
#  'Fullkornspasta Penne 500g Kungsörnen',
#  'Cashewnötter 500g ICA Gott Liv',
#  'Bryggkaffe Mellanrost perfekt med mjölk 450g Löfbergs',
#  'Oliver Halkidiki Urkärnade 500g ICA',
#  'Körsbärstomater Pomodorini di collina 400g Mutti',
#  'Fajita Kryddmix Original Medium 28g Santa Maria',
#  'Asia Sweet Chili Sås Original 500ml Santa Maria',
#  'Sojasås Teriyaki 300ml ICA Asia',
#  'Ketchup 1kg Heinz',
#  'Strösocker 2kg ICA',
#  'Skivade & inlagda Rödbetor 560g ICA',
#  'Kokosmjölk 200ml ICA Asia',
#  'Tonfisk i vatten 3-p 285g Abba',
#  'Havregryn 1,5kg ICA',
#  'Tortillachips Ost 450g ICA Basic',
#  'Timjan 15g Santa Maria',
#  'Pasta Spaghetti 1000g Barilla',
#  'Tomater krossade 500g ICA Basic',
#  'Mini Taco Tubs 10p Santa Maria',
#  'Müsli Tranbär & pumpafrön 750g ICA Gott Liv',
#  'Havregryn 1kg Gyllenhammars',
#  'Krossade Tomater 390g KRAV ICA I love eco',
#  'Rostad lök 150g ICA',
#  'Oliver Grekiska Gröna Urkärnade 227g ICA',
#  'Köttbuljong 12-p 6l Knorr',
#  'Kalvfond 180ml Touch of Taste',
#  'Äggnudlar 250g ICA Asia',
#  'Bearnaise 450ml Rydbergs',
#  'Kikärtor 380g ICA',
#  'Kanel Malen 40g Santa Maria',
#  'Teriyakisås 300ml Santa Maria',
#  'Riven Kokos 200g ICA',
#  'Pasta Gemelli 500g ICA',
#  'Pasta Spaghetti Glutenfri 400g Barilla',
#  'Dip Nacho Cheese Style 250g Santa Maria',
#  'Nyponsoppa 1l lCA',
#  'Strösocker 1kg ICA',
#  'Salt Finkornigt med Jod 600g Falksalt',
#  'Pesto Tomat 185g ICA',
#  'Nudlar Champinjonsmak 85g Samyang',
#  'Majs 3-p 480g Green Giant',
#  'Kidneybönor 380g ICA',
#  'Stora Bönor Vita 380g ICA',
#  'Bryggkaffe Franskrost 500g Arvid Nordquist Classic',
#  'Finkrossade Tomater Polpa 400g Mutti',
#  'Smörgåsgurka 715g Felix',
#  'Kaffe GranDia 500g Arvid Nordquist Classic',
#  'Passerade tomater 390g ICA',
#  'Olivolja Mild 500ml ICA',
#  'Dippmix Guacamole 15g Santa Maria',
#  'Pasta Tortellini Ost & Skinka Färsk 250g ICA',
#  'Soft tortillas Large 6-p 370g ICA',
#  'Curry 34g Santa Maria',
#  'Blåbärssoppa Original 1l Ekströms',
#  'Redning Ljus 250g Maizena',
#  'Pilsnerkorv 455g Bullens',
#  'Kikärtor 380g ICA I Love Eco',
#  'Ris Långkornigt 1kg Ben´s Original',
#  'Jäst för matbröd 50g Kronjäst',
#  'Pesto Basilika 185g ICA',
#  'Ättika 12% 500ml ICA',
#  'Tonfisk i vatten 200g Abba',
#  'Nudlar Biff 85g Samyang',
#  'Pasta Strozzapreti 400g Zeta',
#  'Majskorn 150g 3-pack ICA Basic',
#  'Kryddmix Chicken Thai Wok påse 30g Santa Maria',
#  'Nacho Chips 185g Santa Maria',
#  'Kokosmjölk Lätt 400ml ICA Asia',
#  'Risnudlar 180g Santa Maria',
#  'Strösocker 2kg Dansukker',
#  'Svenska Havrekuddar 375g ICA',
#  'Krossade tomater 3-p 1170g ICA',
#  'Havreringar Fullkorn 350g Frebaco',
#  'Vetemjöl 2kg ICA',
#  'Farfalle 500g ICA',
#  'Kryddmix Asian Spices Paneng Red curry 32g Santa Maria',
#  'Oxfond med Rödvin 180ml Touch of Taste',
#  'Kokosgrädde 400ml ICA Asia',
#  'Tortillachips Cheese 200g ICA',
#  'Kakao Ögon Cacao 400g Fazer',
#  'Pumpakärnor 300g Risenta',
#  'Nacho Chips 475g Santa Maria',
#  'Jordgubbskräm 1l ICA',
#  'Jordnötssmör crunchy med havssalt 600g ICA I love eco',
#  'Bulgur 500g ICA',
#  'Currysås 2,25dl 3-p Blå Band',
#  'Vita bönor i tomatsås 380g ICA Basic',
#  'Kaffefilter Nummer 4 200p ICA Basic',
#  'Vetemjöl 2kg Kungsörnen',
#  'Granola Hasseln&Dadlar 450g Pauluns',
#  'Special K Classic 600g Kelloggs',
#  'Tomatpuré 360g ICA',
#  'Linguine 800g Zeta',
#  'Kokosmjölk Ekologisk 400ml ICA',
#  'Nyponsoppa utan tillsatt socker 1l Ekströms',
#  'Champinjoner Hela 290g ICA',
#  'Vitlökspulver Malen 52g ICA',
#  'Pineapple Salsa 230g Santa Maria',
#  'Gnocchi Pasta 500g ICA',
#  'Risnudlar 180g ICA Asia',
#  'Finkrossade Tomater Vitlök 390g ICA',
#  'Tacosås Medium 220g ICA',
#  'Penne Rigate 500g ICA',
#  'Ugn & grillfolie 40cm 10m ICA',
#  'Salladskrydda Italiensk 52g Santa Maria',
#  'Pasta Risoni 500g Barilla',
#  'Krydda Svartpeppar Hel påse 70g Santa Maria',
#  'Fryspåsar 3l 30-p Miljömärk ICA Basic',
#  'Russin Kärnfria 500g ICA',
#  'Cheerios Fullkorn 375g Nestle',
#  'Svartpeppar Mellanmalen 30g Santa Maria',
#  'Pasta Spirali Tricolore 500g ICA',
#  'Pasta Rigatoni 500g Barilla',
#  'Pasta Fusilli Glutenfri 400g Barilla',
#  'Majs 3p 450g ICA',
#  'Pastasås Basilico 400g Barilla',
#  'Pasta Penne Rigate 500g ICA Basic',
#  'Pizzasås Tomat 400g Mutti',
#  'Rapsolja 1l ICA',
#  'Tomatsås Basilika 400g Mutti',
#  'Köttfärssås Original 500g Findus',
#  'Sötmandel 400g ICA Basic',
#  'Fusilli Fullkorn 500g Kungsörnen',
#  'Müsli Gold Original 750g AXA',
#  'Nudlar Oriental 85g Samyang',
#  'Kokosmjölk 400ml ICA Asia',
#  'Pastasås Tomatsås med Vitlök 390g ICA',
#  'Flingor Crunchy Yoghurt & jordgubb Mindre socker 725g ICA',
#  'Pasta Penne Rigate 500g Barilla',
#  'Bakchoklad Vit 100g ICA',
#  'Finkrossade Tomater Basilika 390g ICA',
#  'Gräddsås Klassisk 3dl 3-p Blå Band',
#  'Snabbmakaroner 1kg ICA Basic',
#  'Jasminris Boil in bag 500g Ben´s Original',
#  'Tonfisk i vatten 170g ICA Basic',
#  'Classic sticks 47g Dextro Energy',
#  ...]

# %%
# 1. embed recipes
model = SentenceTransformer('all-MiniLM-L6-v2')
# model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
recipe_texts = []
for r in RECIPES:
    title = str(r.get("Title") or r.get("title") or "")  # 转为字符串，避免NaN
    ingredients = r.get("Ingredients") or r.get("ingredients") or ""
    
    # 如果 ingredients 是字符串形式的列表，需要转成 Python list
    if isinstance(ingredients, str):
        try:
            ingredients_list = ast.literal_eval(ingredients)  # 将 "['1 cup sugar', ...]" 转为列表
        except:
            ingredients_list = [ingredients]
    else:
        ingredients_list = ingredients
    
    ingredients_text = " ".join([str(i) for i in ingredients_list])
    recipe_texts.append(title + " " + ingredients_text)

recipes_embeddings = model.encode(recipe_texts, convert_to_numpy=True)

# 2. create FAISS index
d = recipes_embeddings.shape[1]
recipe_index = faiss.IndexFlatL2(d)
recipe_index.add(recipes_embeddings)
faiss.write_index(recipe_index, "recipes_index.faiss")
np.save("recipes_embeddings.npy", recipes_embeddings)

# %%
model = SentenceTransformer('KBLab/sentence-bert-swedish-cased')
product_embeddings = model.encode(product_names, convert_to_numpy=True, show_progress_bar=True)
faiss.normalize_L2(product_embeddings)

product_dim = product_embeddings.shape[1]
product_index = faiss.IndexFlatL2(product_dim)
product_index.add(product_embeddings)
faiss.write_index(product_index, "product_index.faiss")
np.save("product_embeddings.npy", product_embeddings)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/118 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/710 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/107 [00:00<?, ?it/s]

# %%
# 加载 FAISS 索引
recipe_index = faiss.read_index("recipes_index.faiss")

# 如果你保存了 embeddings，可以直接加载
recipe_embeddings = np.load("recipes_embeddings.npy")

# %%
def retrieve_recipes(query, top_k=5):
    model = SentenceTransformer('all-MiniLM-L6-v2')
    query_emb = model.encode([query])
    distances, indices = recipe_index.search(query_emb, top_k)
    return [RECIPES[i] for i in indices[0]]

# %%
def retrieve_products(ingredients, top_k=5):
    query_emb = model.encode([ingredients])
    distances, indices = product_index.search(query_emb, top_k)
    return [PRODUCTS[i] for i in indices[0] if i < len(PRODUCTS)]

# %%
query = "give me some vegetarian recipes "
retrieved = retrieve_recipes(query, top_k=5)

# %%
context_text = "\n".join([f"- {r['title']}: {r.get('instructions', '')}, {r.get('ingredients', [])}" for r in retrieved])
context_text
# Out:
# '- Vegetarian Buffalo “Meatballs” With Blue Cheese Dip: Arrange a rack in center of oven and preheat to 400°F. Coat a rimmed baking sheet with oil.\nPulse garlic in a food processor until finely chopped. Add celery, beans, and mushrooms and pulse until coarsely chopped. Transfer to a large bowl. Stir in egg, panko, and 3/4 tsp. salt. Using your hands, roll tablespoonfuls of bean mixture into balls. Transfer to prepared baking sheet, packing them snuggly. Roast veggie balls, turning halfway through, until firm and cooked through, 25–30 minutes.\nMeanwhile, cook butter, hot sauce, and maple syrup in a small saucepan over medium heat until butter is melted. Stir until smooth; set aside.\nWhisk sour cream, buttermilk, blue cheese, pepper, 1 Tbsp. plus 2 tsp. chives, and remaining 1/4 tsp. salt in a medium bowl. Top with remaining 1 tsp. chives.\nTransfer veggie balls to a large bowl. Toss with hot sauce mixture and serve with blue cheese dip alongside.\nVeggie balls can be formed, not cooked, 1 day ahead; cover and chill., [\'1 tablespoon vegetable oil\', \'2 garlic cloves\', \'1 celery stalk, coarsely chopped\', \'1 (15-ounce) can white beans, rinsed, drained\', \'4 ounces button mushrooms\', \'1 large egg\', \'1 cup panko (Japanese breadcrumbs)\', \'1 teaspoon kosher salt, divided\', \'5 tablespoons unsalted butter\', "1/2 cup hot pepper sauce, preferably Frank\'s", \'2 tablespoons pure maple syrup\', \'1/2 cup sour cream\', \'1/4 cup buttermilk\', \'1/4 cup crumbled blue cheese\', \'1/2 teaspoon freshly ground black pepper\', \'2 tablespoons chopped chives, divided\']\n- Vegetarian Spring Rolls: 1. Heat 1 tablespoon of the oil in a large skillet or wok over medium heat.\n2. Add the onions, saute for 2 minutes. Add in garlic, ginger, carrots and mushrooms and saute for 3 minutes.\n3. Add the cabbage, kale, scallions and salt and saute an additional 3 minutes.\n4. In a small bowl, whisk together the soy sauce, rice vinegar and sesame oil, and add it to the skillet. Stir to coat the veggies well. Remove from the heat and allow to cool slightly.\n5. Place one spring roll wrapper on a flat surface in front of you, with a corner facing you, so it makes a diamond shape.\n6. Place 2 tablespoons of the filling in a line in middle of the wrapper.\n7. Fold the corners toward the center on top of the filling and the bottom corner over the top of the filing. Brush a little water on the top corner and roll it up like a burrito.\n8. Heat the remaining 3 tablespoons oil in the skillet or wok over medium heat.\n9. Place a few spring rolls in the pan, making sure you have room to roll them. Cook them on each side for 2–5 minutes, until they are golden brown on each side. Each spring roll will take about 7–10 minutes to fully cook., [\'4 tablespoons coconut oil, divided\', \'1 small yellow onion, finely diced\', \'1 garlic clove, minced\', \'1 teaspoon freshly grated ginger\', \'1 large carrot, grated, about 1 1/2 cups\', \'6–8 shiitake mushrooms, diced\', \'1 cup thinly sliced kale\', \'1 cup thinly sliced napa cabbage\', \'1 scallion, diced\', \'1/2 teaspoon salt\', \'1/4 cup low sodium soy sauce\', \'1 tablespoon rice vinegar\', \'1 teaspoon sesame oil\', \'12 spring roll wrappers\']\n- Vegetarian Cassoulet: Halve leeks lengthwise and cut crosswise into 1/2-inch pieces, then wash well and pat dry.\nCook leeks, carrots, celery, and garlic in oil with herb sprigs, bay leaf, cloves, and 1/2 teaspoon each of salt and pepper in a large heavy pot over medium heat, stirring occasionally, until softened and golden, about 15 minutes. Stir in beans, then water, and simmer, partially covered, stirring occasionally, until carrots are tender but not falling apart, about 30 minutes.\nPreheat oven to 350°F with rack in middle.\nToss bread crumbs with oil, garlic, and 1/4 teaspoon each of salt and pepper in a bowl until well coated. Spread in a baking pan and toast in oven, stirring once halfway through, until crisp and golden, 12 to 15 minutes.\nCool crumbs  ...

# %%
def slugify(title: str) -> str:
    s = re.sub(r"[^a-zA-Z0-9]+", "-", title.lower()).strip("-")
    return s[:80]

# Precompute IDs for recipes
for r in RECIPES:
    r["id"] = slugify(str(r["title"] if "title" in r else r.get("Title", "")) or str(r.get("title","")))
    if not r["id"]:
        r["id"] = slugify(r.get("Title","untitled"))

# %%
def _rec_title(r):
    return r.get("title") or r.get("Title") or "Untitled"

def parse_ingredients_field(val):
    """Recipes CSV stores ingredients as a python-ish list string."""
    if isinstance(val, list):
        return val
    s = str(val)
    try:
        out = ast.literal_eval(s)
        if isinstance(out, list):
            return [str(x) for x in out]
    except Exception:
        pass
    # fallback: split by commas
    return [x.strip() for x in s.split(",") if x.strip()]

def split_instructions(s: str):
    raw = str(s).replace("\r\n", "\n").replace("\r", "\n")
    parts = [p.strip(" \t") for p in raw.split("\n") if p.strip()]
    if len(parts) <= 1:
        # fallback to sentence-ish split
        parts = [p.strip() for p in re.split(r"\.\s+", raw) if p.strip()]
    return parts

# %%
import numpy as np

def recipe_detail_payload(r, sim_threshold: float = 0.3):
    model = SentenceTransformer('KBLab/sentence-bert-swedish-cased')
    title = _rec_title(r)
    ingredients = parse_ingredients_field(r.get("ingredients") or r.get("Ingredients",""))
    steps = split_instructions(r.get("instructions") or r.get("Instructions",""))

    ing_texts = [ing.lower() for ing in ingredients]
    ing_embeddings = model.encode(ing_texts, convert_to_numpy=True, show_progress_bar=False)
    faiss.normalize_L2(ing_embeddings)

    product_embeddings = np.load("product_embeddings.npy")
    sims = ing_embeddings @ product_embeddings.T  # shape = (num_ingredients, num_products)

    # --- 用向量匹配找到每个 ingredient 的最佳产品 ---
    mapped_links = []
    for i, ing in enumerate(ingredients):
        best_idx = int(np.argmax(sims[i]))
        best_score = float(sims[i, best_idx])

        if best_score < sim_threshold:
            mapped_links.append({
                "ingredient": ing,
                "product_name": None,
                "store": None,
                "price": None,
                "url": None
            })
            continue
        
        best_prod = PRODUCTS[best_idx]
        mapped_links.append({
            "ingredient": ing,
            "product_name": best_prod["name"],
            "store": best_prod.get("store"),
            "price": best_prod.get("price"),
            "url": best_prod.get("url", ""),
            "similarity": round(best_score, 3)
        })

    return {
        "id": r["id"],
        "title": title,
        "ingredients": ingredients,
        "steps": steps,
        "where_to_buy": mapped_links
    }

# %%
retrieved[0]
# Out:
# {'title': 'Vegetarian Buffalo “Meatballs” With Blue Cheese Dip',
#  'ingredients': '[\'1 tablespoon vegetable oil\', \'2 garlic cloves\', \'1 celery stalk, coarsely chopped\', \'1 (15-ounce) can white beans, rinsed, drained\', \'4 ounces button mushrooms\', \'1 large egg\', \'1 cup panko (Japanese breadcrumbs)\', \'1 teaspoon kosher salt, divided\', \'5 tablespoons unsalted butter\', "1/2 cup hot pepper sauce, preferably Frank\'s", \'2 tablespoons pure maple syrup\', \'1/2 cup sour cream\', \'1/4 cup buttermilk\', \'1/4 cup crumbled blue cheese\', \'1/2 teaspoon freshly ground black pepper\', \'2 tablespoons chopped chives, divided\']',
#  'instructions': 'Arrange a rack in center of oven and preheat to 400°F. Coat a rimmed baking sheet with oil.\nPulse garlic in a food processor until finely chopped. Add celery, beans, and mushrooms and pulse until coarsely chopped. Transfer to a large bowl. Stir in egg, panko, and 3/4 tsp. salt. Using your hands, roll tablespoonfuls of bean mixture into balls. Transfer to prepared baking sheet, packing them snuggly. Roast veggie balls, turning halfway through, until firm and cooked through, 25–30 minutes.\nMeanwhile, cook butter, hot sauce, and maple syrup in a small saucepan over medium heat until butter is melted. Stir until smooth; set aside.\nWhisk sour cream, buttermilk, blue cheese, pepper, 1 Tbsp. plus 2 tsp. chives, and remaining 1/4 tsp. salt in a medium bowl. Top with remaining 1 tsp. chives.\nTransfer veggie balls to a large bowl. Toss with hot sauce mixture and serve with blue cheese dip alongside.\nVeggie balls can be formed, not cooked, 1 day ahead; cover and chill.',
#  'image': 'vegetarian-buffalo-meatballs-with-blue-cheese-dip',
#  'cleaned_ingredients': '[\'1 tablespoon vegetable oil\', \'2 garlic cloves\', \'1 celery stalk, coarsely chopped\', \'1 (15-ounce) can white beans, rinsed, drained\', \'4 ounces button mushrooms\', \'1 large egg\', \'1 cup panko (Japanese breadcrumbs)\', \'1 teaspoon kosher salt, divided\', \'5 tablespoons unsalted butter\', \'"1/2 cup hot pepper sauce, preferably Franks", 2 tablespoons pure maple syrup\', \'1/2 cup sour cream\', \'1/4 cup buttermilk\', \'1/4 cup crumbled blue cheese\', \'1/2 teaspoon freshly ground black pepper\', \'2 tablespoons chopped chives\', \'divided\']',
#  'id': 'vegetarian-buffalo-meatballs-with-blue-cheese-dip'}

# %%
recipe_detail_payload(retrieved[0])
# Out:
# {'id': 'vegetarian-buffalo-meatballs-with-blue-cheese-dip',
#  'title': 'Vegetarian Buffalo “Meatballs” With Blue Cheese Dip',
#  'ingredients': ['1 tablespoon vegetable oil',
#   '2 garlic cloves',
#   '1 celery stalk, coarsely chopped',
#   '1 (15-ounce) can white beans, rinsed, drained',
#   '4 ounces button mushrooms',
#   '1 large egg',
#   '1 cup panko (Japanese breadcrumbs)',
#   '1 teaspoon kosher salt, divided',
#   '5 tablespoons unsalted butter',
#   "1/2 cup hot pepper sauce, preferably Frank's",
#   '2 tablespoons pure maple syrup',
#   '1/2 cup sour cream',
#   '1/4 cup buttermilk',
#   '1/4 cup crumbled blue cheese',
#   '1/2 teaspoon freshly ground black pepper',
#   '2 tablespoons chopped chives, divided'],
#  'steps': ['Arrange a rack in center of oven and preheat to 400°F. Coat a rimmed baking sheet with oil.',
#   'Pulse garlic in a food processor until finely chopped. Add celery, beans, and mushrooms and pulse until coarsely chopped. Transfer to a large bowl. Stir in egg, panko, and 3/4 tsp. salt. Using your hands, roll tablespoonfuls of bean mixture into balls. Transfer to prepared baking sheet, packing them snuggly. Roast veggie balls, turning halfway through, until firm and cooked through, 25–30 minutes.',
#   'Meanwhile, cook butter, hot sauce, and maple syrup in a small saucepan over medium heat until butter is melted. Stir until smooth; set aside.',
#   'Whisk sour cream, buttermilk, blue cheese, pepper, 1 Tbsp. plus 2 tsp. chives, and remaining 1/4 tsp. salt in a medium bowl. Top with remaining 1 tsp. chives.',
#   'Transfer veggie balls to a large bowl. Toss with hot sauce mixture and serve with blue cheese dip alongside.',
#   'Veggie balls can be formed, not cooked, 1 day ahead; cover and chill.'],
#  'where_to_buy': [{'ingredient': '1 tablespoon vegetable oil',
#    'product_name': 'Olivolja Mild 500ml ICA',
#    'store': 'Ica',
#    'price': '74,00',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/olivolja-mild-500ml-ica/1433613',
#    'similarity': 0.763},
#   {'ingredient': '2 garlic cloves',
#    'product_name': 'Oliver Vitlök',
#    'store': 'Hemköp',
#    'price': '25,95',
#    'url': 'https://www.hemkop.se/produkt/Oliver-Vitlok-101618365_ST',
#    'similarity': 0.618},
#   {'ingredient': '1 celery stalk, coarsely chopped',
#    'product_name': 'Skogaholmslimpa skivad 775g Skogaholms',
#    'store': 'Ica',
#    'price': '37,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/skogaholmslimpa-skivad-775g-skogaholms/1024401',
#    'similarity': 0.585},
#   {'ingredient': '1 (15-ounce) can white beans, rinsed, drained',
#    'product_name': 'Vita bönor i tomatsås 380g ICA Basic',
#    'store': 'Ica',
#    'price': '9,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/vita-b%C3%B6nor-i-tomats%C3%A5s-380g-ica-basic/2116926',
#    'similarity': 0.75},
#   {'ingredient': '4 ounces button mushrooms',
#    'product_name': 'Svampsoppa 3 portioner 6dl Varma Koppen',
#    'store': 'Ica',
#    'price': '20,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/svampsoppa-3-portioner-6dl-varma-koppen/1008263',
#    'similarity': 0.627},
#   {'ingredient': '1 large egg',
#    'product_name': 'Äggvita Pastöriserad flytande 1kg Kronägg',
#    'store': 'Ica',
#    'price': '51,00',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/%C3%A4ggvita-past%C3%B6riserad-flytande-1kg-kron%C3%A4gg/1455719',
#    'similarity': 0.685},
#   {'ingredient': '1 cup panko (Japanese breadcrumbs)',
#    'product_name': 'Knäckebröd Din Stund Mini Chia & Havssalt 270g Wasa',
#    'store': 'Ica',
#    'price': '44,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/kn%C3%A4ckebr%C3%B6d-din-stund-mini-chia-havssalt-270g-wasa/2080288',
#    'similarity': 0.657},
#   {'ingredient': '1 teaspoon kosher salt, divided',
#    'product_name': 'Salt Finkornigt med Jod 600g Falksalt',
#    'store': 'Ica',
#    'price': '17,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/salt-finkornigt-med-jod-600g-falksalt/1006123',
#    'similarity': 0.788},
#   {'ingredient': '5 tablespoons unsalted butter',
#    'product_name': 'Smör & Raps Normalsaltat 75% 500g Bregott®',
#    'store': 'Ica',
#    'price': '69,00',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/sm%C3%B6r-raps-normalsaltat-75-500g-bregott/2129122',
#    'similarity': 0.738},
#   {'ingredient': "1/2 cup hot pepper sauce, preferably Frank's",
#    'product_name': 'Pepparsås 230ml Eriks såser',
#    'store': 'Ica',
#    'price': '35,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/peppars%C3%A5s-230ml-eriks-s%C3%A5ser/1354064',
#    'similarity': 0.817},
#   {'ingredient': '2 tablespoons pure maple syrup',
#    'product_name': 'Vaniljsås 10% 250ml Oatly',
#    'store': 'Ica',
#    'price': '15,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/vaniljs%C3%A5s-10-250ml-oatly/1270701',
#    'similarity': 0.674},
#   {'ingredient': '1/2 cup sour cream',
#    'product_name': 'Vispgrädde 36% 5dl Arla Köket®',
#    'store': 'Ica',
#    'price': '48,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/vispgr%C3%A4dde-36-5dl-arla-k%C3%B6ket/1315805',
#    'similarity': 0.791},
#   {'ingredient': '1/4 cup buttermilk',
#    'product_name': 'Smör & Raps Normalsaltat 75% 250g Bregott®',
#    'store': 'Ica',
#    'price': '43,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/sm%C3%B6r-raps-normalsaltat-75-250g-bregott/2129114',
#    'similarity': 0.766},
#   {'ingredient': '1/4 cup crumbled blue cheese',
#    'product_name': 'Ädel Grädd 36% Blåmögelost 140g Kvibille®',
#    'store': 'Ica',
#    'price': '42,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/%C3%A4del-gr%C3%A4dd-36-bl%C3%A5m%C3%B6gelost-140g-kvibille/1131646',
#    'similarity': 0.779},
#   {'ingredient': '1/2 teaspoon freshly ground black pepper',
#    'product_name': 'Svartpeppar grovmalen 65g ICA Basic',
#    'store': 'Ica',
#    'price': '21,90',
#    'url': 'https://handlaprivatkund.ica.se/stores/1004181/products/svartpeppar-grovmalen-65g-ica-basic/2112954',
#    'similarity': 0.757},
#   {'ingredient': '2 tablespoons chopped chives, divided',
#    'product_name': 'Hushålls Medwurst Skivad',
#    'store': 'Hemköp',
#    'price': '26,95',
#    'url': 'https://www.hemkop.se/produkt/Hushalls-Medwurst-Skivad-101599343_ST',
#    'similarity': 0.636}]}

# %%
retrieved
# Out:
# [{'title': 'Vegetarian Buffalo “Meatballs” With Blue Cheese Dip',
#   'ingredients': '[\'1 tablespoon vegetable oil\', \'2 garlic cloves\', \'1 celery stalk, coarsely chopped\', \'1 (15-ounce) can white beans, rinsed, drained\', \'4 ounces button mushrooms\', \'1 large egg\', \'1 cup panko (Japanese breadcrumbs)\', \'1 teaspoon kosher salt, divided\', \'5 tablespoons unsalted butter\', "1/2 cup hot pepper sauce, preferably Frank\'s", \'2 tablespoons pure maple syrup\', \'1/2 cup sour cream\', \'1/4 cup buttermilk\', \'1/4 cup crumbled blue cheese\', \'1/2 teaspoon freshly ground black pepper\', \'2 tablespoons chopped chives, divided\']',
#   'instructions': 'Arrange a rack in center of oven and preheat to 400°F. Coat a rimmed baking sheet with oil.\nPulse garlic in a food processor until finely chopped. Add celery, beans, and mushrooms and pulse until coarsely chopped. Transfer to a large bowl. Stir in egg, panko, and 3/4 tsp. salt. Using your hands, roll tablespoonfuls of bean mixture into balls. Transfer to prepared baking sheet, packing them snuggly. Roast veggie balls, turning halfway through, until firm and cooked through, 25–30 minutes.\nMeanwhile, cook butter, hot sauce, and maple syrup in a small saucepan over medium heat until butter is melted. Stir until smooth; set aside.\nWhisk sour cream, buttermilk, blue cheese, pepper, 1 Tbsp. plus 2 tsp. chives, and remaining 1/4 tsp. salt in a medium bowl. Top with remaining 1 tsp. chives.\nTransfer veggie balls to a large bowl. Toss with hot sauce mixture and serve with blue cheese dip alongside.\nVeggie balls can be formed, not cooked, 1 day ahead; cover and chill.',
#   'image': 'vegetarian-buffalo-meatballs-with-blue-cheese-dip',
#   'cleaned_ingredients': '[\'1 tablespoon vegetable oil\', \'2 garlic cloves\', \'1 celery stalk, coarsely chopped\', \'1 (15-ounce) can white beans, rinsed, drained\', \'4 ounces button mushrooms\', \'1 large egg\', \'1 cup panko (Japanese breadcrumbs)\', \'1 teaspoon kosher salt, divided\', \'5 tablespoons unsalted butter\', \'"1/2 cup hot pepper sauce, preferably Franks", 2 tablespoons pure maple syrup\', \'1/2 cup sour cream\', \'1/4 cup buttermilk\', \'1/4 cup crumbled blue cheese\', \'1/2 teaspoon freshly ground black pepper\', \'2 tablespoons chopped chives\', \'divided\']',
#   'id': 'vegetarian-buffalo-meatballs-with-blue-cheese-dip'},
#  {'title': 'Vegetarian Spring Rolls',
#   'ingredients': "['4 tablespoons coconut oil, divided', '1 small yellow onion, finely diced', '1 garlic clove, minced', '1 teaspoon freshly grated ginger', '1 large carrot, grated, about 1 1/2 cups', '6–8 shiitake mushrooms, diced', '1 cup thinly sliced kale', '1 cup thinly sliced napa cabbage', '1 scallion, diced', '1/2 teaspoon salt', '1/4 cup low sodium soy sauce', '1 tablespoon rice vinegar', '1 teaspoon sesame oil', '12 spring roll wrappers']",
#   'instructions': '1. Heat 1 tablespoon of the oil in a large skillet or wok over medium heat.\n2. Add the onions, saute for 2 minutes. Add in garlic, ginger, carrots and mushrooms and saute for 3 minutes.\n3. Add the cabbage, kale, scallions and salt and saute an additional 3 minutes.\n4. In a small bowl, whisk together the soy sauce, rice vinegar and sesame oil, and add it to the skillet. Stir to coat the veggies well. Remove from the heat and allow to cool slightly.\n5. Place one spring roll wrapper on a flat surface in front of you, with a corner facing you, so it makes a diamond shape.\n6. Place 2 tablespoons of the filling in a line in middle of the wrapper.\n7. Fold the corners toward the center on top of the filling and the bottom corner over the top of the filing. Brush a little water on the top corner and roll it up like a burrito.\n8. Heat the remaining 3 tablespoons oil in the skillet or wok over medium heat.\n9. Place a few spring rolls in the pan, making sure you have room to roll them. Cook them on each side for 2–5 minutes, until they are golden brown on each side. Each spring roll will take about 7–10 minutes to fully cook.',
#   'image': 'vegetarian-spring-rolls-56389478',
#   'cleaned_ingredients': "['4 tablespoons coconut oil, divided', '1 small yellow onion, finely diced', '1 garlic clove, minced', '1 teaspoon freshly grated ginger', '1 large carrot, grated, about 1 1/2 cups', '6–8 shiitake mushrooms, diced', '1 cup thinly sliced kale', '1 cup thinly sliced napa cabbage', '1 scallion, diced', '1/2 teaspoon salt', '1/4 cup low sodium soy sauce', '1 tablespoon rice vinegar', '1 teaspoon sesame oil', '12 spring roll wrappers']",
#   'id': 'vegetarian-spring-rolls'},
#  {'title': 'Vegetarian Cassoulet',
#   'ingredients': "['3 medium leeks (white and pale green parts only)', '4 medium carrots, halved lengthwise and cut into 1-inch-wide pieces', '3 celery ribs, cut into 1-inch-wide pieces', '4 garlic cloves, chopped', '1/4 cup olive oil', '4 thyme sprigs', '2 parsley sprigs', '1 Turkish or 1/2 California bay leaf', '1/8 teaspoon ground cloves', '3 (19-ounce) cans cannellini or Great Northern beans, rinsed and drained', '1 quart water', '4 cups coarse fresh bread crumbs from a baguette', '1/3 cup olive oil', '1 tablespoon chopped garlic', '1/4 cup chopped parsley']",
#   'instructions': 'Halve leeks lengthwise and cut crosswise into 1/2-inch pieces, then wash well and pat dry.\nCook leeks, carrots, celery, and garlic in oil with herb sprigs, bay leaf, cloves, and 1/2 teaspoon each of salt and pepper in a large heavy pot over medium heat, stirring occasionally, until softened and golden, about 15 minutes. Stir in beans, then water, and simmer, partially covered, stirring occasionally, until carrots are tender but not falling apart, about 30 minutes.\nPreheat oven to 350°F with rack in middle.\nToss bread crumbs with oil, garlic, and 1/4 teaspoon each of salt and pepper in a bowl until well coated. Spread in a baking pan and toast in oven, stirring once halfway through, until crisp and golden, 12 to 15 minutes.\nCool crumbs in pan, then return to bowl and stir in parsley.\nDiscard herb sprigs and bay leaf. Mash some of beans in pot with a potato masher or back of a spoon to thicken broth. Season with salt and pepper. Just before serving, sprinkle with garlic crumbs.',
#   'image': 'vegetarian-cassoulet-241753',
#   'cleaned_ingredients': "['3 medium leeks (white and pale green parts only)', '4 medium carrots, halved lengthwise and cut into 1-inch-wide pieces', '3 celery ribs, cut into 1-inch-wide pieces', '4 garlic cloves, chopped', '1/4 cup olive oil', '4 thyme sprigs', '2 parsley sprigs', '1 Turkish or 1/2 California bay leaf', '1/8 teaspoon ground cloves', '3 (19-ounce) cans cannellini or Great Northern beans, rinsed and drained', '1 quart water', '4 cups coarse fresh bread crumbs from a baguette', '1/3 cup olive oil', '1 tablespoon chopped garlic', '1/4 cup chopped parsley']",
#   'id': 'vegetarian-cassoulet'},
#  {'title': 'Tempeh "Bacon," Lettuce, and Tomato Sandwich',
#   'ingredients': "['1 batch Tempeh Bacon', '2 cups cherry tomatoes (about 10 ounces), halved', '2 tablespoons regular or vegan mayonnaise', '4 slices sourdough bread, grilled or toasted', '1/2 large avocado, thinly sliced just before serving', '1/4 cup basil leaves, coarsely torn', '2 crisp romaine leaves']",
#   'instructions': 'Prepare marinade for Tempeh Bacon in a shallow dish, adding tomatoes along with tempeh. Cover and chill at least 2 hours or up to 4.\nPreheat oven to 400°F and line a rimmed baking sheet with parchment paper. Arrange tempeh on one-half of sheet and tomatoes on remaining half in a single layer. Bake, tossing tempeh and basting with marinade after 10 minutes, until tempeh is crispy and tomatoes are shrunken and sweet, 30–33 minutes.\nDivide mayonnaise between 2 slices of bread. Top with tempeh and roasted tomatoes. Arrange avocado slices, basil, and romaine over, then top with remaining slices to close sandwich.',
#   'image': 'tempeh-bacon-lettuce-and-tomato-sandwich',
#   'cleaned_ingredients': "['1 batch Tempeh Bacon', '2 cups cherry tomatoes (about 10 ounces), halved', '2 tablespoons regular or vegan mayonnaise', '4 slices sourdough bread, grilled or toasted', '1/2 large avocado, thinly sliced just before serving', '1/4 cup basil leaves, coarsely torn', '2 crisp romaine leaves']",
#   'id': 'tempeh-bacon-lettuce-and-tomato-sandwich'},
#  {'title': 'Vegetarian Tagine',
#   'ingredients': "['1 tablespoon olive oil', '1 small onion, diced', '1 garlic clove, minced', '1 stalk celery, diced', '1 carrot, diced', '1 teaspoon paprika', '1/2 teaspoon ground cinnamon', '1/2 teaspoon ground cumin', '1/2 teaspoon fresh ginger, grated or 1/4 teaspoon ground ginger', '2 teaspoons salt', '1 (14.5-ounce) can diced tomatoes', '1 small butternut squash, peeled and cut into chunks (about 2 cups)', '2 cups cauliflower florets (1 small head)', '2 cups low sodium vegetable broth', '2 cups cooked chickpeas or 1 (15-ounce) can, rinsed and drained', '1/4 cup raisins or currants', '3 cups cooked couscous']",
#   'instructions': '1. Heat the oil in a large pot over medium heat.\n2. Add the onions and garlic and cook for 3 minutes.\n3. Add the celery, carrots, paprika, cinnamon, cumin, ginger and salt. Cook an additional 5 minutes, until the veggies are soft and the spices are fragrant.\n4. Add the tomatoes, butternut squash, cauliflower, and vegetable broth, and stir to combine.\n5. Cover, reduce the heat to low, and simmer for 15–20 minutes.\n6. Stir in the chickpeas and raisins and cook an additional 10–15 minutes or until the vegetables are soft.\n7. Serve over couscous with sliced almonds and green or black olives, if desired.',
#   'image': 'vegetarian-tagine-56389876',
#   'cleaned_ingredients': "['1 tablespoon olive oil', '1 small onion, diced', '1 garlic clove, minced', '1 stalk celery, diced', '1 carrot, diced', '1 teaspoon paprika', '1/2 teaspoon ground cinnamon', '1/2 teaspoon ground cumin', '1/2 teaspoon fresh ginger, grated or 1/4 teaspoon ground ginger', '2 teaspoons salt', '1 (14.5-ounce) can diced tomatoes', '1 small butternut squash, peeled and cut into chunks (about 2 cups)', '2 cups cauliflower florets (1 small head)', '2 cups low sodium vegetable broth', '2 cups cooked chickpeas or 1 (15-ounce) can, rinsed and drained', '1/4 cup raisins or currants', '3 cups cooked couscous']",
#   'id': 'vegetarian-tagine'}]

# %%
parse_ingredients_field(retrieved)
# Out:
# [{'title': 'Vegetarian Buffalo “Meatballs” With Blue Cheese Dip',
#   'ingredients': '[\'1 tablespoon vegetable oil\', \'2 garlic cloves\', \'1 celery stalk, coarsely chopped\', \'1 (15-ounce) can white beans, rinsed, drained\', \'4 ounces button mushrooms\', \'1 large egg\', \'1 cup panko (Japanese breadcrumbs)\', \'1 teaspoon kosher salt, divided\', \'5 tablespoons unsalted butter\', "1/2 cup hot pepper sauce, preferably Frank\'s", \'2 tablespoons pure maple syrup\', \'1/2 cup sour cream\', \'1/4 cup buttermilk\', \'1/4 cup crumbled blue cheese\', \'1/2 teaspoon freshly ground black pepper\', \'2 tablespoons chopped chives, divided\']',
#   'instructions': 'Arrange a rack in center of oven and preheat to 400°F. Coat a rimmed baking sheet with oil.\nPulse garlic in a food processor until finely chopped. Add celery, beans, and mushrooms and pulse until coarsely chopped. Transfer to a large bowl. Stir in egg, panko, and 3/4 tsp. salt. Using your hands, roll tablespoonfuls of bean mixture into balls. Transfer to prepared baking sheet, packing them snuggly. Roast veggie balls, turning halfway through, until firm and cooked through, 25–30 minutes.\nMeanwhile, cook butter, hot sauce, and maple syrup in a small saucepan over medium heat until butter is melted. Stir until smooth; set aside.\nWhisk sour cream, buttermilk, blue cheese, pepper, 1 Tbsp. plus 2 tsp. chives, and remaining 1/4 tsp. salt in a medium bowl. Top with remaining 1 tsp. chives.\nTransfer veggie balls to a large bowl. Toss with hot sauce mixture and serve with blue cheese dip alongside.\nVeggie balls can be formed, not cooked, 1 day ahead; cover and chill.',
#   'image': 'vegetarian-buffalo-meatballs-with-blue-cheese-dip',
#   'cleaned_ingredients': '[\'1 tablespoon vegetable oil\', \'2 garlic cloves\', \'1 celery stalk, coarsely chopped\', \'1 (15-ounce) can white beans, rinsed, drained\', \'4 ounces button mushrooms\', \'1 large egg\', \'1 cup panko (Japanese breadcrumbs)\', \'1 teaspoon kosher salt, divided\', \'5 tablespoons unsalted butter\', \'"1/2 cup hot pepper sauce, preferably Franks", 2 tablespoons pure maple syrup\', \'1/2 cup sour cream\', \'1/4 cup buttermilk\', \'1/4 cup crumbled blue cheese\', \'1/2 teaspoon freshly ground black pepper\', \'2 tablespoons chopped chives\', \'divided\']',
#   'id': 'vegetarian-buffalo-meatballs-with-blue-cheese-dip'},
#  {'title': 'Vegetarian Spring Rolls',
#   'ingredients': "['4 tablespoons coconut oil, divided', '1 small yellow onion, finely diced', '1 garlic clove, minced', '1 teaspoon freshly grated ginger', '1 large carrot, grated, about 1 1/2 cups', '6–8 shiitake mushrooms, diced', '1 cup thinly sliced kale', '1 cup thinly sliced napa cabbage', '1 scallion, diced', '1/2 teaspoon salt', '1/4 cup low sodium soy sauce', '1 tablespoon rice vinegar', '1 teaspoon sesame oil', '12 spring roll wrappers']",
#   'instructions': '1. Heat 1 tablespoon of the oil in a large skillet or wok over medium heat.\n2. Add the onions, saute for 2 minutes. Add in garlic, ginger, carrots and mushrooms and saute for 3 minutes.\n3. Add the cabbage, kale, scallions and salt and saute an additional 3 minutes.\n4. In a small bowl, whisk together the soy sauce, rice vinegar and sesame oil, and add it to the skillet. Stir to coat the veggies well. Remove from the heat and allow to cool slightly.\n5. Place one spring roll wrapper on a flat surface in front of you, with a corner facing you, so it makes a diamond shape.\n6. Place 2 tablespoons of the filling in a line in middle of the wrapper.\n7. Fold the corners toward the center on top of the filling and the bottom corner over the top of the filing. Brush a little water on the top corner and roll it up like a burrito.\n8. Heat the remaining 3 tablespoons oil in the skillet or wok over medium heat.\n9. Place a few spring rolls in the pan, making sure you have room to roll them. Cook them on each side for 2–5 minutes, until they are golden brown on each side. Each spring roll will take about 7–10 minutes to fully cook.',
#   'image': 'vegetarian-spring-rolls-56389478',
#   'cleaned_ingredients': "['4 tablespoons coconut oil, divided', '1 small yellow onion, finely diced', '1 garlic clove, minced', '1 teaspoon freshly grated ginger', '1 large carrot, grated, about 1 1/2 cups', '6–8 shiitake mushrooms, diced', '1 cup thinly sliced kale', '1 cup thinly sliced napa cabbage', '1 scallion, diced', '1/2 teaspoon salt', '1/4 cup low sodium soy sauce', '1 tablespoon rice vinegar', '1 teaspoon sesame oil', '12 spring roll wrappers']",
#   'id': 'vegetarian-spring-rolls'},
#  {'title': 'Vegetarian Cassoulet',
#   'ingredients': "['3 medium leeks (white and pale green parts only)', '4 medium carrots, halved lengthwise and cut into 1-inch-wide pieces', '3 celery ribs, cut into 1-inch-wide pieces', '4 garlic cloves, chopped', '1/4 cup olive oil', '4 thyme sprigs', '2 parsley sprigs', '1 Turkish or 1/2 California bay leaf', '1/8 teaspoon ground cloves', '3 (19-ounce) cans cannellini or Great Northern beans, rinsed and drained', '1 quart water', '4 cups coarse fresh bread crumbs from a baguette', '1/3 cup olive oil', '1 tablespoon chopped garlic', '1/4 cup chopped parsley']",
#   'instructions': 'Halve leeks lengthwise and cut crosswise into 1/2-inch pieces, then wash well and pat dry.\nCook leeks, carrots, celery, and garlic in oil with herb sprigs, bay leaf, cloves, and 1/2 teaspoon each of salt and pepper in a large heavy pot over medium heat, stirring occasionally, until softened and golden, about 15 minutes. Stir in beans, then water, and simmer, partially covered, stirring occasionally, until carrots are tender but not falling apart, about 30 minutes.\nPreheat oven to 350°F with rack in middle.\nToss bread crumbs with oil, garlic, and 1/4 teaspoon each of salt and pepper in a bowl until well coated. Spread in a baking pan and toast in oven, stirring once halfway through, until crisp and golden, 12 to 15 minutes.\nCool crumbs in pan, then return to bowl and stir in parsley.\nDiscard herb sprigs and bay leaf. Mash some of beans in pot with a potato masher or back of a spoon to thicken broth. Season with salt and pepper. Just before serving, sprinkle with garlic crumbs.',
#   'image': 'vegetarian-cassoulet-241753',
#   'cleaned_ingredients': "['3 medium leeks (white and pale green parts only)', '4 medium carrots, halved lengthwise and cut into 1-inch-wide pieces', '3 celery ribs, cut into 1-inch-wide pieces', '4 garlic cloves, chopped', '1/4 cup olive oil', '4 thyme sprigs', '2 parsley sprigs', '1 Turkish or 1/2 California bay leaf', '1/8 teaspoon ground cloves', '3 (19-ounce) cans cannellini or Great Northern beans, rinsed and drained', '1 quart water', '4 cups coarse fresh bread crumbs from a baguette', '1/3 cup olive oil', '1 tablespoon chopped garlic', '1/4 cup chopped parsley']",
#   'id': 'vegetarian-cassoulet'},
#  {'title': 'Tempeh "Bacon," Lettuce, and Tomato Sandwich',
#   'ingredients': "['1 batch Tempeh Bacon', '2 cups cherry tomatoes (about 10 ounces), halved', '2 tablespoons regular or vegan mayonnaise', '4 slices sourdough bread, grilled or toasted', '1/2 large avocado, thinly sliced just before serving', '1/4 cup basil leaves, coarsely torn', '2 crisp romaine leaves']",
#   'instructions': 'Prepare marinade for Tempeh Bacon in a shallow dish, adding tomatoes along with tempeh. Cover and chill at least 2 hours or up to 4.\nPreheat oven to 400°F and line a rimmed baking sheet with parchment paper. Arrange tempeh on one-half of sheet and tomatoes on remaining half in a single layer. Bake, tossing tempeh and basting with marinade after 10 minutes, until tempeh is crispy and tomatoes are shrunken and sweet, 30–33 minutes.\nDivide mayonnaise between 2 slices of bread. Top with tempeh and roasted tomatoes. Arrange avocado slices, basil, and romaine over, then top with remaining slices to close sandwich.',
#   'image': 'tempeh-bacon-lettuce-and-tomato-sandwich',
#   'cleaned_ingredients': "['1 batch Tempeh Bacon', '2 cups cherry tomatoes (about 10 ounces), halved', '2 tablespoons regular or vegan mayonnaise', '4 slices sourdough bread, grilled or toasted', '1/2 large avocado, thinly sliced just before serving', '1/4 cup basil leaves, coarsely torn', '2 crisp romaine leaves']",
#   'id': 'tempeh-bacon-lettuce-and-tomato-sandwich'},
#  {'title': 'Vegetarian Tagine',
#   'ingredients': "['1 tablespoon olive oil', '1 small onion, diced', '1 garlic clove, minced', '1 stalk celery, diced', '1 carrot, diced', '1 teaspoon paprika', '1/2 teaspoon ground cinnamon', '1/2 teaspoon ground cumin', '1/2 teaspoon fresh ginger, grated or 1/4 teaspoon ground ginger', '2 teaspoons salt', '1 (14.5-ounce) can diced tomatoes', '1 small butternut squash, peeled and cut into chunks (about 2 cups)', '2 cups cauliflower florets (1 small head)', '2 cups low sodium vegetable broth', '2 cups cooked chickpeas or 1 (15-ounce) can, rinsed and drained', '1/4 cup raisins or currants', '3 cups cooked couscous']",
#   'instructions': '1. Heat the oil in a large pot over medium heat.\n2. Add the onions and garlic and cook for 3 minutes.\n3. Add the celery, carrots, paprika, cinnamon, cumin, ginger and salt. Cook an additional 5 minutes, until the veggies are soft and the spices are fragrant.\n4. Add the tomatoes, butternut squash, cauliflower, and vegetable broth, and stir to combine.\n5. Cover, reduce the heat to low, and simmer for 15–20 minutes.\n6. Stir in the chickpeas and raisins and cook an additional 10–15 minutes or until the vegetables are soft.\n7. Serve over couscous with sliced almonds and green or black olives, if desired.',
#   'image': 'vegetarian-tagine-56389876',
#   'cleaned_ingredients': "['1 tablespoon olive oil', '1 small onion, diced', '1 garlic clove, minced', '1 stalk celery, diced', '1 carrot, diced', '1 teaspoon paprika', '1/2 teaspoon ground cinnamon', '1/2 teaspoon ground cumin', '1/2 teaspoon fresh ginger, grated or 1/4 teaspoon ground ginger', '2 teaspoons salt', '1 (14.5-ounce) can diced tomatoes', '1 small butternut squash, peeled and cut into chunks (about 2 cups)', '2 cups cauliflower florets (1 small head)', '2 cups low sodium vegetable broth', '2 cups cooked chickpeas or 1 (15-ounce) can, rinsed and drained', '1/4 cup raisins or currants', '3 cups cooked couscous']",
#   'id': 'vegetarian-tagine'}]
